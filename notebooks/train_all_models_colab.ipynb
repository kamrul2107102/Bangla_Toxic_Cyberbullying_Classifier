# %% [markdown]
# # 🚀 Train All Deep Learning Models on Google Colab (Free T4 GPU)
#
# This notebook trains all 3 advanced neural models for **Bangla Toxic & Cyberbullying Classifier**:
# 1. **BiLSTM** (Bidirectional LSTM learned strictly from scratch)
# 2. **Transformer Encoder** (Multi-head self-attention learned strictly from scratch)
# 3. **BanglaBERT** (State-of-the-art pretrained Bengali ELECTRA benchmark)
#
# ---
# ### ⚙️ Step 0: Ensure GPU is Enabled
# Go to **Runtime** ➔ **Change runtime type** ➔ Select **T4 GPU** ➔ Click **Save**.

# %%
# Step 1: Clone or update the repository (Idempotent & Safe)
import os
repo_path = '/content/Bangla_Toxic_Cyberbullying_Classifier'
if not os.path.exists(repo_path):
    # !git clone https://github.com/kamrul2107102/Bangla_Toxic_Cyberbullying_Classifier.git {repo_path}
else:
    # %cd {repo_path}
    # !git pull origin main

# %cd {repo_path}
print('Current directory:', os.getcwd())
# Out:
# /content/Bangla_Toxic_Cyberbullying_Classifier
# From https://github.com/kamrul2107102/Bangla_Toxic_Cyberbullying_Classifier
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# /content/Bangla_Toxic_Cyberbullying_Classifier
# Current directory: /content/Bangla_Toxic_Cyberbullying_Classifier

# %%
# Step 2: Install required deep learning libraries
# !pip install -q torch transformers sentencepiece accelerate pandas numpy joblib

# %%
# Step 3: Train BiLSTM (From Scratch on GPU)
# !python -m src.train --model bilstm --epochs 5
# Out:
# ========================================================
# Training: BiLSTM (from scratch)
# Train samples: 15919 | Val: 1989 | Test: 1991
# ========================================================
#   [BiLSTM] Epoch 1/5 - Loss: 0.4133
#   [BiLSTM] Epoch 2/5 - Loss: 0.3128
#   [BiLSTM] Epoch 3/5 - Loss: 0.2647
#   [BiLSTM] Epoch 4/5 - Loss: 0.2233
#   [BiLSTM] Epoch 5/5 - Loss: 0.1892
#
# --- Evaluation Results [BiLSTM (from scratch)] ---
# Train Time: 18.84s | Inference: 0.10 ms/sample
# Validation Micro-F1: 0.7907 | Macro-F1: 0.7188
# Test Micro-F1:       0.7684 | Macro-F1: 0.6838
# Validation-tuned thresholds: {'hate_speech': 0.45, 'sexist': 0.2, 'threat': 0.25, 'bullying': 0.35, 'toxic': 0.3}
#   hate_speech  - F1: 0.6720, Prec: 0.6857, Rec: 0.6588 (support 1407)
#   sexist       - F1: 0.5573, Prec: 0.4899, Rec: 0.6460 (support 584)
#   threat       - F1: 0.6504, Prec: 0.6283, Rec: 0.6742 (support 1991)
#   bullying     - F1: 0.6500, Prec: 0.6177, Rec: 0.6860 (support 1991)
#   toxic        - F1: 0.8894, Prec: 0.8500, Rec: 0.9326 (support 1991)
#
# Artifacts saved to:
#   - /content/Bangla_Toxic_Cyberbullying_Classifier/artifacts/bilstm.joblib
#   - /content/Bangla_Toxic_Cyberbullying_Classifier/artifacts/bilstm_metrics.json

# %%
# Step 4: Train Transformer Encoder (From Scratch on GPU)
# !python -m src.train --model transformer --epochs 5
# Out:
# ========================================================
# Training: Transformer Encoder (from scratch)
# Train samples: 15919 | Val: 1989 | Test: 1991
# ========================================================
#   [Transformer] Epoch 1/5 - Loss: 0.4531
#   [Transformer] Epoch 2/5 - Loss: 0.3837
#   [Transformer] Epoch 3/5 - Loss: 0.3549
#   [Transformer] Epoch 4/5 - Loss: 0.3364
#   [Transformer] Epoch 5/5 - Loss: 0.3193
# /usr/local/lib/python3.13/dist-packages/torch/nn/modules/transformer.py:531: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. We recommend specifying layout=torch.jagged when constructing a nested tensor, as this layout receives active development, has better operator coverage, and works with torch.compile. (Triggered internally at /pytorch/aten/src/ATen/NestedTensorImpl.cpp:178.)
#   output = torch._nested_tensor_from_mask(
#
# --- Evaluation Results [Transformer Encoder (from scratch)] ---
# Train Time: 21.50s | Inference: 0.10 ms/sample
# Validation Micro-F1: 0.7359 | Macro-F1: 0.6552
# Test Micro-F1:       0.7315 | Macro-F1: 0.6433
# Validation-tuned thresholds: {'hate_speech': 0.25, 'sexist': 0.15, 'threat': 0.4, 'bullying': 0.3, 'toxic': 0.55}
#   hate_speech  - F1: 0.5912, Prec: 0.5387, Rec: 0.6549 (support 1407)
#   sexist       - F1: 0.5217, Prec: 0.4194, Rec: 0.6903 (support 584)
#   threat       - F1: 0.6097, Prec: 0.6185, Rec: 0.6011 (support 1991)
#   bullying     - F1: 0.6239, Prec: 0.5218, Rec: 0.7754 (support 1991)
#   toxic        - F1: 0.8702, Prec: 0.8197, Rec: 0.9273 (support 1991)
#
# Artifacts saved to:
#   - /content/Bangla_Toxic_Cyberbullying_Classifier/artifacts/transformer.joblib
#   - /content/Bangla_Toxic_Cyberbullying_Classifier/artifacts/transformer_metrics.json

# %%
# Step 5: Fine-tune BanglaBERT (CSE BUET ELECTRA on GPU)
# !python -m src.train --model banglabert --epochs 3
# Out:
# ========================================================
# Training: BanglaBERT (External Pretrained Benchmark)
# >> Note: External Pretrained Benchmark (CSE BUET NLP ELECTRA)
# Train samples: 15919 | Val: 1989 | Test: 1991
# ========================================================
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 197/197 [00:00<00:00, 13294.04it/s]
# [transformers] ElectraForSequenceClassification LOAD REPORT from: csebuetnlp/banglabert
# Key                                               | Status     |
# --------------------------------------------------+------------+-
# discriminator_predictions.dense_prediction.weight | UNEXPECTED |
# discriminator_predictions.dense.bias              | UNEXPECTED |
# discriminator_predictions.dense.weight            | UNEXPECTED |
# discriminator_predictions.dense_prediction.bias   | UNEXPECTED |
# classifier.out_proj.weight                        | MISSING    |
# classifier.dense.bias                             | MISSING    |
# classifier.out_proj.bias                          | MISSING    |
# classifier.dense.weight                           | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [BanglaBERT] Epoch 1/3 - Loss: 0.5111
#   [BanglaBERT] Epoch 2/3 - Loss: 0.4576
#   [BanglaBERT] Epoch 3/3 - Loss: 0.4292
#
# --- Evaluation Results [BanglaBERT (External Pretrained Benchmark)] ---
# Train Time: 170.63s | Inference: 3.28 ms/sample
# Validation Micro-F1: 0.6407 | Macro-F1: 0.5300
# Test Micro-F1:       0.6292 | Macro-F1: 0.5162
# Validation-tuned thresholds: {'hate_speech': 0.25, 'sexist': 0.15, 'threat': 0.15, 'bullying': 0.25, 'toxic': 0.5}
#   hate_speech  - F1: 0.4681, Prec: 0.4017, Rec: 0.5608 (support 1407)
#   sexist       - F1: 0.3616, Prec: 0.2284, Rec: 0.8673 (support 584)
#   threat       - F1: 0.3810, Prec: 0.3439, Rec: 0.4270 (support 1991)
#   bullying     - F1: 0.5429, Prec: 0.4224, Rec: 0.7596 (support 1991)
#   toxic        - F1: 0.8276, Prec: 0.7839, Rec: 0.8765 (support 1991)
# Writing model shards: 100% 1/1 [00:06<00:00,  6.13s/it]
#
# Artifacts saved to:
#   - /content/Bangla_Toxic_Cyberbullying_Classifier/artifacts/banglabert.joblib
#   - /content/Bangla_Toxic_Cyberbullying_Classifier/artifacts/banglabert_metrics.json

# %%
# Step 6: Generate Full Comparison Report
# !python -m src.evaluation.compare_models
# Out:
# Skipping Naive Bayes (artifact naive_bayes.joblib not found)
# Skipping TF-IDF + Logistic Regression (artifact tfidf_lr.joblib not found)
# Skipping Word2Vec + Logistic Regression (artifact word2vec_lr.joblib not found)
# Evaluating BiLSTM on 1991 test samples...
# /usr/local/lib/python3.13/dist-packages/torch/nn/modules/rnn.py:1169: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters(). (Triggered internally at /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1479.)
#   result = _VF.lstm(
# Evaluating Transformer Encoder on 1991 test samples...
# /usr/local/lib/python3.13/dist-packages/torch/nn/modules/transformer.py:531: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. We recommend specifying layout=torch.jagged when constructing a nested tensor, as this layout receives active development, has better operator coverage, and works with torch.compile. (Triggered internally at /pytorch/aten/src/ATen/NestedTensorImpl.cpp:178.)
#   output = torch._nested_tensor_from_mask(
# Evaluating BanglaBERT (Reference Benchmark) on 1991 test samples...
#
# Comparison report generated at: docs/model_comparison.md

# %%
# Step 7: Package all trained artifacts and automatically download to your PC
# !zip -r trained_artifacts.zip artifacts/
from google.colab import files
files.download('trained_artifacts.zip')
print('✅ Artifacts download initiated! Unzip this into your local artifacts/ folder.')
# Out:
# updating: artifacts/ (stored 0%)
# updating: artifacts/bilstm/ (stored 0%)
# updating: artifacts/bilstm/history.json (deflated 59%)
# updating: artifacts/bilstm/thresholds.json (deflated 37%)
# updating: artifacts/bilstm/vocab.json (deflated 77%)
# updating: artifacts/bilstm/config.json (deflated 39%)
# updating: artifacts/README.txt (deflated 26%)
# updating: artifacts/banglabert/ (stored 0%)
# updating: artifacts/banglabert/history.json (deflated 47%)
# updating: artifacts/banglabert/thresholds.json (deflated 37%)
# updating: artifacts/banglabert/train_config.json (deflated 39%)
# updating: artifacts/banglabert/tokenizer_config.json (deflated 46%)
# updating: artifacts/banglabert/tokenizer.json (deflated 76%)
# updating: artifacts/banglabert/config.json (deflated 57%)
# updating: artifacts/scratch/ (stored 0%)
# updating: artifacts/scratch/test_calibration.py (deflated 65%)
# updating: artifacts/scratch/test_nb_calibration.py (deflated 64%)
# updating: artifacts/scratch/test_ngrams.py (deflated 55%)
# updating: artifacts/splits.json (deflated 75%)
# updating: artifacts/transformer/ (stored 0%)
# updating: artifacts/transformer/history.json (deflated 60%)
# updating: artifacts/transformer/thresholds.json (deflated 37%)
# updating: artifacts/transformer/vocab.json (deflated 77%)
# updating: artifacts/transformer/config.json (deflated 39%)
# updating: artifacts/bilstm/model.pt (deflated 6%)
# updating: artifacts/transformer.joblib (deflated 10%)
# updating: artifacts/transformer_metrics.json (deflated 71%)
# updating: artifacts/banglabert/model.safetensors (deflated 7%)
# updating: artifacts/banglabert_metrics.json (deflated 71%)
# updating: artifacts/bilstm_metrics.json (deflated 71%)
# updating: artifacts/transformer/model.pt (deflated 8%)
# updating: artifacts/bilstm.joblib (deflated 8%)
# updating: artifacts/banglabert.joblib (deflated 7%)
# ✅ Artifacts download initiated! Unzip this into your local artifacts/ folder.
